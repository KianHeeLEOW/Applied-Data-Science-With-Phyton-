# %% [markdown]
# # Assignment 4
#
# Before working on this assignment please read these instructions fully. In the submission area, you will notice that you can click the link to **Preview the Grading** for each step of the assignment. This is the criteria that will be used for peer grading. Please familiarize yourself with the criteria before beginning the assignment.
#
# This assignment requires that you to find **at least** two datasets on the web which are related, and that you visualize these datasets to answer a question with the broad topic of **weather phenomena** (see below) for the region of **Singapore, Central Singapore Community Development Council, Singapore**, or **Singapore** more broadly.
#
# You can merge these datasets with data from different regions if you like! For instance, you might want to compare **Singapore, Central Singapore Community Development Council, Singapore** to Ann Arbor, USA. In that case at least one source file must be about **Singapore, Central Singapore Community Development Council, Singapore**.
#
# You are welcome to choose datasets at your discretion, but keep in mind **they will be shared with your peers**, so choose appropriate datasets. Sensitive, confidential, illicit, and proprietary materials are not good choices for datasets for this assignment. You are welcome to upload datasets of your own as well, and link to them using a third party repository such as github, bitbucket, pastebin, etc. Please be aware of the Coursera terms of service with respect to intellectual property.
#
# Also, you are welcome to preserve data in its original language, but for the purposes of grading you should provide english translations. You are welcome to provide multiple visuals in different languages if you would like!
#
# As this assignment is for the whole course, you must incorporate principles discussed in the first week, such as having as high data-ink ratio (Tufte) and aligning with Cairo’s principles of truth, beauty, function, and insight.
#
# Here are the assignment instructions:
#
#  * State the region and the domain category that your data sets are about (e.g., **Singapore, Central Singapore Community Development Council, Singapore** and **weather phenomena**).
#  * You must state a question about the domain category and region that you identified as being interesting.
#  * You must provide at least two links to available datasets. These could be links to files such as CSV or Excel files, or links to websites which might have data in tabular form, such as Wikipedia pages.
#  * You must upload an image which addresses the research question you stated. In addition to addressing the question, this visual should follow Cairo's principles of truthfulness, functionality, beauty, and insightfulness.
#  * You must contribute a short (1-2 paragraph) written justification of how your visualization addresses your stated research question.
#
# What do we mean by **weather phenomena**?  For this category you might want to consider seasonal changes, natural disasters, or historical trends.
#
# ## Tips
# * Wikipedia is an excellent source of data, and I strongly encourage you to explore it for new data sources.
# * Many governments run open data initiatives at the city, region, and country levels, and these are wonderful resources for localized data sources.
# * Several international agencies, such as the [United Nations](http://data.un.org/), the [World Bank](http://data.worldbank.org/), the [Global Open Data Index](http://index.okfn.org/place/) are other great places to look for data.
# * This assignment requires you to convert and clean datafiles. Check out the discussion forums for tips on how to do this from various sources, and share your successes with your fellow students!
#
# ## Example
# Looking for an example? Here's what our course assistant put together for the **Ann Arbor, MI, USA** area using **sports and athletics** as the topic. [Example Solution File](./readonly/Assignment4_example.pdf)

# %%
import glob
import pandas as pd
import os
import csv
import numpy as np

# %%
singaporedf=pd.read_csv('Singapore Data Quality.csv')

# %%
singaporedf_clean=singaporedf[(singaporedf['year']>=2011)]
singaporedf_clean=singaporedf_clean[['year','pm2.5_mean','carbon_monoxide_2nd_maximum_8hourly_mean','nitrogen_dioxide_mean']]
singaporedf_clean.columns = ['Year', 'PM2.5','Carbon monoxide','Nitrogen dioxide']
singaporedf_clean['State Name'] = 'Singapore'
singaporedf_clean
# Out:
#     Year  PM2.5  Carbon monoxide  Nitrogen dioxide State Name
# 12  2011   17.0              2.0                25  Singapore
# 13  2012   19.0              1.9                25  Singapore
# 14  2013   20.0              5.5                25  Singapore
# 15  2014   18.0              1.8                24  Singapore

# %%
usdf=pd.read_csv('US Data Quality.csv')
usdf
# Out:
#                                 Parameter Name  Year         State Name  \
# 0                                        Ozone  2011            Alabama
# 1                                        Ozone  2011            Alabama
# 2                                        Ozone  2011            Alabama
# 3                                        Ozone  2011            Alabama
# 4                         Sample Flow Rate- CV  2011            Alabama
# 5                                Sample Volume  2011            Alabama
# 6                  Average Ambient Temperature  2011            Alabama
# 7                     Average Ambient Pressure  2011            Alabama
# 8                          Elapsed Sample Time  2011            Alabama
# 9                     PM2.5 - Local Conditions  2011            Alabama
# 10                    PM2.5 - Local Conditions  2011            Alabama
# 11                    PM2.5 - Local Conditions  2011            Alabama
# ...

# %%
usdf_clean=usdf[(usdf['Parameter Name']=='PM2.5 - Local Conditions')|(usdf['Parameter Name']=='Nitrogen dioxide (NO2)')| (usdf['Parameter Name']=='Carbon monoxide')]

# %%
usdf_clean
# Out:
#                   Parameter Name  Year         State Name  Arithmetic Mean
# 9       PM2.5 - Local Conditions  2011            Alabama         9.953913
# 10      PM2.5 - Local Conditions  2011            Alabama         9.953913
# 11      PM2.5 - Local Conditions  2011            Alabama         9.953913
# 12      PM2.5 - Local Conditions  2011            Alabama         9.953913
# 18      PM2.5 - Local Conditions  2011            Alabama        10.603390
# 19      PM2.5 - Local Conditions  2011            Alabama        10.603390
# 20      PM2.5 - Local Conditions  2011            Alabama        10.603390
# 21      PM2.5 - Local Conditions  2011            Alabama        10.603390
# 31      PM2.5 - Local Conditions  2011            Alabama        10.324348
# 32      PM2.5 - Local Conditions  2011            Alabama        10.324348
# 33      PM2.5 - Local Conditions  2011            Alabama        10.324348
# ...

# %%
usdf_tidy=usdf_clean.groupby(['State Name', 'Year','Parameter Name'], as_index=False).mean()

# %%
singaporedf_clean2 = pd.melt(singaporedf_clean, id_vars=["State Name","Year"], 
                  var_name="Parameter Name", value_name="Arithmetic Mean")

# %%
singaporedf_clean2
# Out:
#    State Name  Year    Parameter Name  Arithmetic Mean
# 0   Singapore  2011             PM2.5             17.0
# 1   Singapore  2012             PM2.5             19.0
# 2   Singapore  2013             PM2.5             20.0
# 3   Singapore  2014             PM2.5             18.0
# 4   Singapore  2011   Carbon monoxide              2.0
# 5   Singapore  2012   Carbon monoxide              1.9
# 6   Singapore  2013   Carbon monoxide              5.5
# 7   Singapore  2014   Carbon monoxide              1.8
# 8   Singapore  2011  Nitrogen dioxide             25.0
# 9   Singapore  2012  Nitrogen dioxide             25.0
# 10  Singapore  2013  Nitrogen dioxide             25.0
# 11  Singapore  2014  Nitrogen dioxide             24.0

# %%
usdf_tidy
# Out:
#     State Name  Year            Parameter Name  Arithmetic Mean
# 0      Alabama  2011           Carbon monoxide         0.339893
# 1      Alabama  2011  PM2.5 - Local Conditions        11.360150
# 2      Alabama  2012           Carbon monoxide         0.362843
# 3      Alabama  2012  PM2.5 - Local Conditions        10.061938
# 4      Alabama  2013           Carbon monoxide         0.336934
# 5      Alabama  2013    Nitrogen dioxide (NO2)        17.602023
# 6      Alabama  2013  PM2.5 - Local Conditions         9.683860
# 7      Alabama  2014           Carbon monoxide         0.364551
# 8      Alabama  2014    Nitrogen dioxide (NO2)        18.664517
# 9      Alabama  2014  PM2.5 - Local Conditions        10.197786
# 10     Alabama  2015           Carbon monoxide         0.382271
# 11     Alabama  2015    Nitrogen dioxide (NO2)        17.870535
# 12     Alabama  2015  PM2.5 - Local Conditions         9.590448
# 13     Alabama  2016           Carbon monoxide         0.333729
# ...

# %%
#Append the 2 data frames together
combineddf=singaporedf_clean2.append(usdf_tidy,ignore_index=True)

# %%
#Standardise the Paramter Name fields
di = {"PM2.5 - Local Conditions": "PM2.5", "Nitrogen dioxide (NO2)": "Nitrogen dioxide"}
combineddf=combineddf.replace({"Parameter Name": di})

# %%
combineddf
# Out:
#     State Name  Year    Parameter Name  Arithmetic Mean
# 0    Singapore  2011             PM2.5        17.000000
# 1    Singapore  2012             PM2.5        19.000000
# 2    Singapore  2013             PM2.5        20.000000
# 3    Singapore  2014             PM2.5        18.000000
# 4    Singapore  2011   Carbon monoxide         2.000000
# 5    Singapore  2012   Carbon monoxide         1.900000
# 6    Singapore  2013   Carbon monoxide         5.500000
# 7    Singapore  2014   Carbon monoxide         1.800000
# 8    Singapore  2011  Nitrogen dioxide        25.000000
# 9    Singapore  2012  Nitrogen dioxide        25.000000
# 10   Singapore  2013  Nitrogen dioxide        25.000000
# 11   Singapore  2014  Nitrogen dioxide        24.000000
# 12     Alabama  2011   Carbon monoxide         0.339893
# 13     Alabama  2011             PM2.5        11.360150
# 14     Alabama  2012   Carbon monoxide         0.362843
# 15     Alabama  2012             PM2.5        10.061938
# ...

# %%
#filter other states except for Singapore, New York, Alaska, Texas and Washington
#View mean PM2.5 index
import matplotlib.pyplot as plt
import seaborn as sns
fig, ax = plt.subplots(figsize=(10, 10))
filtereddf=combineddf[(combineddf['State Name']=='Singapore')| (combineddf['State Name']=='New York')| (combineddf['State Name']=='Texas')| (combineddf['State Name']=='Washington')| (combineddf['State Name']=='Alaska')]
sns.pointplot(x='Year', y='Arithmetic Mean', hue='State Name', data=filtereddf[(combineddf['Parameter Name']=='PM2.5')])
sns.despine(fig)
plt.title('PM2.5 Index')
plt.legend();
plt.show()
# Out:
# /opt/conda/lib/python3.5/site-packages/ipykernel/__main__.py:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /opt/conda/lib/python3.5/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
